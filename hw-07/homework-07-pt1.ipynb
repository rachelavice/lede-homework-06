# %% [markdown]
# Part One
#
# Scrape the list of Arizona-based rock and mineral clubs from https://rocktumbler.com/blog/rock-and-mineral-clubs/Links to an external site. using pandas and save them as a CSV.
#
# Tips:
#
# No requests necessary!
# Check the 03 - Tables.ipynb notebook from class

# %%
# %pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import html5lib

# %%
tables = pd.read_html("http://rocktumbler.com/blog/rock-and-mineral-clubs/")
arizona_df=tables[5]

# %%
arizona_df.head()
# Out:
#                                     0                  1
# 0   Apache Junction Rock and Gem Club    Apache Junction
# 1         Black Canyon City Rock Club  Black Canyon City
# 2  Daisy Mountain Rock & Mineral Club             Anthem
# 3   Gila County Gem & Mineral Society              Miami
# 4       Huachuca Mineral and Gem Club       Sierra Vista

# %%
arizona_df.to_csv('arizona_rock_mineral_clubs.csv', ind)
